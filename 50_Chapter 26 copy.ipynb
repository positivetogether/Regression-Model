# %%
##################### Python 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic'
import numpy as np
import os
import datetime
import dcor
import math
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)
import warnings
from scipy import stats
from PIL import Image
warnings.filterwarnings('ignore')
from scipy.stats import chi2
import os
os.chdir('/Users/sss/Desktop/Data')
os.getcwd()
from IPython.core.display import display, HTML
#display(HTML("<style>.container { width: 60% !important; }</style>"))
plt.rcParams['font.family'] = 'AppleGothic'
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
df = pd.read_csv("chapter26_df.csv")

# %%
df
# Out:
#      EDUCATION  SOUTH  SEX  EXPERIENCE  UNION   WAGE  AGE  RACE  OCCUPATION  \
# 0            8      0    1          21      0   5.10   35     2           6
# 1            9      0    1          42      0   4.95   57     3           6
# 2           12      0    0           1      0   6.67   19     3           6
# 3           12      0    0           4      0   4.00   22     3           6
# 4           12      0    0          17      0   7.50   35     3           6
# ..         ...    ...  ...         ...    ...    ...  ...   ...         ...
# 529         18      0    0           5      0  11.36   29     3           5
# 530         12      0    1          33      0   6.10   51     1           5
# 531         17      0    1          25      1  23.25   48     1           5
# 532         12      1    0          13      1  19.88   31     3           5
# 533         16      0    0          33      0  15.38   55     3           5
#
#      SECTOR  MARR
# 0         1     1
# ...

# %%
df.columns
# Out:
# Index(['EDUCATION', 'SOUTH', 'SEX', 'EXPERIENCE', 'UNION', 'WAGE', 'AGE',
#        'RACE', 'OCCUPATION', 'SECTOR', 'MARR'],
#       dtype='object')

# %%
df  = df[['EDUCATION', 'SOUTH', 'SEX', 'EXPERIENCE', 'UNION', 'AGE',
       'RACE', 'OCCUPATION', 'SECTOR', 'MARR', 'WAGE']]

# %%
df
# Out:
#      EDUCATION  SOUTH  SEX  EXPERIENCE  UNION  AGE  RACE  OCCUPATION  SECTOR  \
# 0            8      0    1          21      0   35     2           6       1
# 1            9      0    1          42      0   57     3           6       1
# 2           12      0    0           1      0   19     3           6       1
# 3           12      0    0           4      0   22     3           6       0
# 4           12      0    0          17      0   35     3           6       0
# ..         ...    ...  ...         ...    ...  ...   ...         ...     ...
# 529         18      0    0           5      0   29     3           5       0
# 530         12      0    1          33      0   51     1           5       0
# 531         17      0    1          25      1   48     1           5       0
# 532         12      1    0          13      1   31     3           5       0
# 533         16      0    0          33      0   55     3           5       1
#
#      MARR   WAGE
# 0       1   5.10
# ...

# %%
df.hist()
plt.gcf().set_size_inches(15,15)

# %%
Image.open('Screenshot 2024-04-14 at 4.57.59 PM.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1084x756>

# %%
df.describe()
# Out:
#         EDUCATION       SOUTH         SEX  EXPERIENCE       UNION         AGE  \
# count  534.000000  534.000000  534.000000  534.000000  534.000000  534.000000
# mean    13.018727    0.292135    0.458801   17.822097    0.179775   36.833333
# std      2.615373    0.455170    0.498767   12.379710    0.384360   11.726573
# min      2.000000    0.000000    0.000000    0.000000    0.000000   18.000000
# 25%     12.000000    0.000000    0.000000    8.000000    0.000000   28.000000
# 50%     12.000000    0.000000    0.000000   15.000000    0.000000   35.000000
# 75%     15.000000    1.000000    1.000000   26.000000    0.000000   44.000000
# max     18.000000    1.000000    1.000000   55.000000    1.000000   64.000000
#
#              RACE  OCCUPATION      SECTOR        MARR        WAGE
# count  534.000000   534.00000  534.000000  534.000000  534.000000
# mean     2.698502     4.14794    0.275281    0.655431    9.024064
# std      0.679999     1.65580    0.538453    0.475673    5.139097
# ...

# %%
df.isnull().sum()
# Out:
# EDUCATION     0
# SOUTH         0
# SEX           0
# EXPERIENCE    0
# UNION         0
# AGE           0
# RACE          0
# OCCUPATION    0
# SECTOR        0
# MARR          0
# WAGE          0
# dtype: int64

# %%
df.shape
# Out:
# (534, 11)

# %%
df
# Out:
#      EDUCATION  SOUTH  SEX  EXPERIENCE  UNION  AGE  RACE  OCCUPATION  SECTOR  \
# 0            8      0    1          21      0   35     2           6       1
# 1            9      0    1          42      0   57     3           6       1
# 2           12      0    0           1      0   19     3           6       1
# 3           12      0    0           4      0   22     3           6       0
# 4           12      0    0          17      0   35     3           6       0
# ..         ...    ...  ...         ...    ...  ...   ...         ...     ...
# 529         18      0    0           5      0   29     3           5       0
# 530         12      0    1          33      0   51     1           5       0
# 531         17      0    1          25      1   48     1           5       0
# 532         12      1    0          13      1   31     3           5       0
# 533         16      0    0          33      0   55     3           5       1
#
#      MARR   WAGE
# 0       1   5.10
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [EDUCATION, SOUTH, SEX, EXPERIENCE, UNION, AGE, RACE, OCCUPATION, SECTOR, MARR, WAGE]
# Index: []

# %%
df['EDUCATION'].value_counts()
# Out:
# EDUCATION
# 12    219
# 16     71
# 14     56
# 13     37
# 18     31
# 11     27
# 17     24
# 10     17
# 8      15
# 15     13
# 9      12
# 7       5
# 6       3
# 5       1
# 3       1
# 4       1
# 2       1
# Name: count, dtype: int64

# %%
for i in df.columns:
    print('===========================')
    print(df[i].value_counts())
    
    
### SOUTH SEX UNION MARR SECTOR OCCUPATION RACE
# Out:
# ...
# EDUCATION
# 12    219
# 16     71
# 14     56
# 13     37
# 18     31
# 11     27
# 17     24
# 10     17
# 8      15
# 15     13
# 9      12
# 7       5
# 6       3
# 5       1
# 3       1
# 4       1
# 2       1
# Name: count, dtype: int64
# ...
# SOUTH
# 0    378
# 1    156
# Name: count, dtype: int64
# ...
# SEX
# 0    289
# 1    245
# Name: count, dtype: int64
# ...
# EXPERIENCE
# 14    28
# 13    23
# 10    23
# 16    22
# 8     19
#       ..
# 47     2
# 55     1
# 54     1
# 48     1
# 49     1
# Name: count, Length: 52, dtype: int64
# ...
# UNION
# 0    438
# 1     96
# Name: count, dtype: int64
# ...
# AGE
# 32    24
# 26    22
# 36    21
# 34    20
# 33    20
# 35    18
# 37    18
# 29    18
# 38    18
# 28    18
# 27    17
# 25    17
# 30    17
# 31    16
# 42    15
# 20    14
# 24    13
# 43    13
# 22    13
# 21    12
# 41    12
# 44    11
# 39    10
# 19    10
# 53     9
# 57     9
# 61     9
# 51     9
# 55     9
# 23     8
# 56     8
# 46     8
# 45     7
# 47     7
# 52     7
# 54     7
# ...

# %%
### MARR SECTOR OCCUPATION RACE

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.gcf().set_size_inches(15,15)

# %%
df.groupby(['EDUCATION'])['WAGE'].mean().sort_values(ascending=False)
# Out:
# EDUCATION
# 5     14.000000
# 17    13.615000
# 18    13.530968
# 14    11.022321
# 16    10.824366
# 15    10.673846
# 13     7.835135
# 12     7.787078
# 9      7.331667
# 10     7.318235
# 3      7.000000
# 11     6.584444
# 4      6.000000
# 8      5.978667
# 7      5.770000
# 6      4.456667
# 2      3.750000
# Name: WAGE, dtype: float64

# %%
for i in df.columns:
    print('==================================')
    print(df.groupby([i])['WAGE'].mean().sort_values(ascending=False))
# Out:
# ...
# EDUCATION
# 5     14.000000
# 17    13.615000
# 18    13.530968
# 14    11.022321
# 16    10.824366
# 15    10.673846
# 13     7.835135
# 12     7.787078
# 9      7.331667
# 10     7.318235
# 3      7.000000
# 11     6.584444
# 4      6.000000
# 8      5.978667
# 7      5.770000
# 6      4.456667
# 2      3.750000
# Name: WAGE, dtype: float64
# ...
# SOUTH
# 0    9.489233
# 1    7.896923
# Name: WAGE, dtype: float64
# ...
# SEX
# 0    9.994913
# 1    7.878857
# Name: WAGE, dtype: float64
# ...
# EXPERIENCE
# 40    16.003333
# 31    15.557500
# 32    13.410000
# 18    12.326364
# 44    11.450000
#         ...
# 54     6.000000
# 2      5.568667
# 0      4.528182
# 48     3.500000
# 49     3.400000
# Name: WAGE, Length: 52, dtype: float64
# ...
# UNION
# 1    10.798125
# 0     8.635228
# Name: WAGE, dtype: float64
# ...
# AGE
# 40    14.452000
# 41    13.169167
# 58    12.905000
# 55    12.897778
# 48    12.870000
# 39    11.929000
# 64    11.815000
# 54    11.507143
# 44    11.455455
# 61    11.060000
# ...

# %%
df
# Out:
#      EDUCATION  SOUTH  SEX  EXPERIENCE  UNION  AGE  RACE  OCCUPATION  SECTOR  \
# 0            8      0    1          21      0   35     2           6       1
# 1            9      0    1          42      0   57     3           6       1
# 2           12      0    0           1      0   19     3           6       1
# 3           12      0    0           4      0   22     3           6       0
# 4           12      0    0          17      0   35     3           6       0
# ..         ...    ...  ...         ...    ...  ...   ...         ...     ...
# 529         18      0    0           5      0   29     3           5       0
# 530         12      0    1          33      0   51     1           5       0
# 531         17      0    1          25      1   48     1           5       0
# 532         12      1    0          13      1   31     3           5       0
# 533         16      0    0          33      0   55     3           5       1
#
#      MARR   WAGE
# 0       1   5.10
# ...

# %%
sns.scatterplot(data=df, x='EDUCATION', y='WAGE')
plt.show()

# %%
for i in df.columns:
    sns.scatterplot(data=df, x=i, y='WAGE')
    plt.show()

# %%
df
# Out:
#      EDUCATION  SOUTH  SEX  EXPERIENCE  UNION  AGE  RACE  OCCUPATION  SECTOR  \
# 0            8      0    1          21      0   35     2           6       1
# 1            9      0    1          42      0   57     3           6       1
# 2           12      0    0           1      0   19     3           6       1
# 3           12      0    0           4      0   22     3           6       0
# 4           12      0    0          17      0   35     3           6       0
# ..         ...    ...  ...         ...    ...  ...   ...         ...     ...
# 529         18      0    0           5      0   29     3           5       0
# 530         12      0    1          33      0   51     1           5       0
# 531         17      0    1          25      1   48     1           5       0
# 532         12      1    0          13      1   31     3           5       0
# 533         16      0    0          33      0   55     3           5       1
#
#      MARR   WAGE
# 0       1   5.10
# ...

# %%
for i, col in enumerate(df.columns):
    plt.subplot(5,5,i+1)
    sns.boxplot(x=df[col])

# %%
df
# Out:
#      EDUCATION  SOUTH  SEX  EXPERIENCE  UNION  AGE  RACE  OCCUPATION  SECTOR  \
# 0            8      0    1          21      0   35     2           6       1
# 1            9      0    1          42      0   57     3           6       1
# 2           12      0    0           1      0   19     3           6       1
# 3           12      0    0           4      0   22     3           6       0
# 4           12      0    0          17      0   35     3           6       0
# ..         ...    ...  ...         ...    ...  ...   ...         ...     ...
# 529         18      0    0           5      0   29     3           5       0
# 530         12      0    1          33      0   51     1           5       0
# 531         17      0    1          25      1   48     1           5       0
# 532         12      1    0          13      1   31     3           5       0
# 533         16      0    0          33      0   55     3           5       1
#
#      MARR   WAGE
# 0       1   5.10
# ...

# %%
# !pip install optbinning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 534 entries, 0 to 533
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EDUCATION   534 non-null    int64
#  1   SOUTH       534 non-null    int64
#  2   SEX         534 non-null    int64
#  3   EXPERIENCE  534 non-null    int64
#  4   UNION       534 non-null    int64
#  5   AGE         534 non-null    int64
#  6   RACE        534 non-null    int64
#  7   OCCUPATION  534 non-null    int64
#  8   SECTOR      534 non-null    int64
#  9   MARR        534 non-null    int64
#  10  WAGE        534 non-null    float64
# dtypes: float64(1), int64(10)
# memory usage: 46.0 KB

# %%
### SOUTH SEX UNION MARR SECTOR OCCUPATION RACE

# %%
categorical_list =  [ 'SOUTH', 'SEX', 'UNION', 'MARR', 'SECTOR', 'OCCUPATION', 'RACE' ]

# %%
categorical_list
# Out:
# ['SOUTH', 'SEX', 'UNION', 'MARR', 'SECTOR', 'OCCUPATION', 'RACE']

# %%
numerical_list =  []
for i in df.columns:
    if i not in categorical_list:
        numerical_list.append(i)

# %%
numerical_list
# Out:
# ['EDUCATION', 'EXPERIENCE', 'AGE', 'WAGE']

# %%
df[categorical_list]
# Out:
#      SOUTH  SEX  UNION  MARR  SECTOR  OCCUPATION  RACE
# 0        0    1      0     1       1           6     2
# 1        0    1      0     1       1           6     3
# 2        0    0      0     0       1           6     3
# 3        0    0      0     0       0           6     3
# 4        0    0      0     1       0           6     3
# ..     ...  ...    ...   ...     ...         ...   ...
# 529      0    0      0     0       0           5     3
# 530      0    1      0     1       0           5     1
# 531      0    1      1     1       0           5     1
# 532      1    0      1     1       0           5     3
# 533      0    0      0     1       1           5     3
#
# [534 rows x 7 columns]

# %%
df_categorical  = df[categorical_list]

# %%
df_categorical['WAGE'] = df['WAGE']

# %%
df_categorical
# Out:
#      SOUTH  SEX  UNION  MARR  SECTOR  OCCUPATION  RACE   WAGE
# 0        0    1      0     1       1           6     2   5.10
# 1        0    1      0     1       1           6     3   4.95
# 2        0    0      0     0       1           6     3   6.67
# 3        0    0      0     0       0           6     3   4.00
# 4        0    0      0     1       0           6     3   7.50
# ..     ...  ...    ...   ...     ...         ...   ...    ...
# 529      0    0      0     0       0           5     3  11.36
# 530      0    1      0     1       0           5     1   6.10
# 531      0    1      1     1       0           5     1  23.25
# 532      1    0      1     1       0           5     3  19.88
# 533      0    0      0     1       1           5     3  15.38
#
# [534 rows x 8 columns]

# %%
df_categorical.groupby('SOUTH')['WAGE'].mean()
# Out:
# SOUTH
# 0    9.489233
# 1    7.896923
# Name: WAGE, dtype: float64

# %%
for i in categorical_list:
    print('=======================================')
    print(df_categorical.groupby(i)['WAGE'].mean())
    sns.barplot(x=df_categorical.groupby(i)['WAGE'].mean().index, y=df_categorical.groupby(i)['WAGE'].mean() )
    plt.show()
# Out:
# ...
# SOUTH
# 0    9.489233
# 1    7.896923
# Name: WAGE, dtype: float64
# ...
# SEX
# 0    9.994913
# 1    7.878857
# Name: WAGE, dtype: float64
# ...
# UNION
# 0     8.635228
# 1    10.798125
# Name: WAGE, dtype: float64
# ...
# MARR
# 0    8.311848
# 1    9.398486
# Name: WAGE, dtype: float64
# ...
# SECTOR
# 0    8.872774
# 1    9.604444
# 2    9.220833
# Name: WAGE, dtype: float64
# ...
# OCCUPATION
# 1    12.704000
# 2     7.592632
# 3     7.422577
# 4     6.537470
# 5    11.947429
# 6     8.426474
# Name: WAGE, dtype: float64
# ...
# RACE
# 1    8.058358
# 2    7.283333
# 3    9.277932
# Name: WAGE, dtype: float64

# %%
from sklearn.model_selection import cross_val_score, KFold, train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import xgboost as xgb
import lightgbm as lgb
import tensorflow as tf
# Out:
# 2024-04-17 13:54:47.911139: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
X = df.drop('WAGE', axis=1)
Y = df['WAGE']

x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.3)

# %%
import statsmodels.api as sm

# %%
X_constant = sm.add_constant(X)

# %%
X_constant
# Out:
#      const  EDUCATION  SOUTH  SEX  EXPERIENCE  UNION  AGE  RACE  OCCUPATION  \
# 0      1.0          8      0    1          21      0   35     2           6
# 1      1.0          9      0    1          42      0   57     3           6
# 2      1.0         12      0    0           1      0   19     3           6
# 3      1.0         12      0    0           4      0   22     3           6
# 4      1.0         12      0    0          17      0   35     3           6
# ..     ...        ...    ...  ...         ...    ...  ...   ...         ...
# 529    1.0         18      0    0           5      0   29     3           5
# 530    1.0         12      0    1          33      0   51     1           5
# 531    1.0         17      0    1          25      1   48     1           5
# 532    1.0         12      1    0          13      1   31     3           5
# 533    1.0         16      0    0          33      0   55     3           5
#
#      SECTOR  MARR
# 0         1     1
# ...

# %%
ols_model = sm.OLS(Y, X_constant)

# %%
result = ols_model.fit().summary()

# %%
result
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   WAGE   R-squared:                       0.280
# Model:                            OLS   Adj. R-squared:                  0.267
# Method:                 Least Squares   F-statistic:                     20.39
# Date:                Wed, 17 Apr 2024   Prob (F-statistic):           5.37e-32
# Time:                        13:54:59   Log-Likelihood:                -1543.4
# No. Observations:                 534   AIC:                             3109.
# Df Residuals:                     523   BIC:                             3156.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.0402      6.879     -0.297      0.767     -15.554      11.474
# ...

# %%
model = sm.OLS(Y, X_constant)

# %%
result = model.fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   WAGE   R-squared:                       0.280
# Model:                            OLS   Adj. R-squared:                  0.267
# Method:                 Least Squares   F-statistic:                     20.39
# Date:                Wed, 17 Apr 2024   Prob (F-statistic):           5.37e-32
# Time:                        13:54:59   Log-Likelihood:                -1543.4
# No. Observations:                 534   AIC:                             3109.
# Df Residuals:                     523   BIC:                             3156.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.0402      6.879     -0.297      0.767     -15.554      11.474
# ...

# %%
r2_score(Y,result.predict(X_constant))
# Out:
# 0.280491230905932

# %%
result.summary().tables[0]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
result_df = pd.DataFrame(result.summary().tables[1])

# %%
result_df.iloc[0:,]
# Out:
#              0           1          2          3       4          5          6
# 0                     coef    std err          t   P>|t|     [0.025     0.975]
# 1        const     -2.0402      6.879     -0.297   0.767    -15.554     11.474
# 2    EDUCATION      1.3262      1.108      1.197   0.232     -0.851      3.503
# 3        SOUTH     -0.6975      0.428     -1.628   0.104     -1.539      0.144
# 4          SEX     -2.1443      0.399     -5.370   0.000     -2.929     -1.360
# 5   EXPERIENCE      0.5246      1.109      0.473   0.636     -1.653      2.703
# 6        UNION      1.5168      0.525      2.889   0.004      0.485      2.548
# 7          AGE     -0.4282      1.108     -0.386   0.699     -2.605      1.748
# 8         RACE      0.4786      0.285      1.676   0.094     -0.082      1.039
# 9   OCCUPATION     -0.1527      0.131     -1.165   0.245     -0.410      0.105
# 10      SECTOR      0.7190      0.388      1.855   0.064     -0.042      1.480
# ...

# %%
result_df.columns = result_df.iloc[0]

# %%
result_df
# Out:
# 0                     coef    std err          t   P>|t|     [0.025     0.975]
# 0                     coef    std err          t   P>|t|     [0.025     0.975]
# 1        const     -2.0402      6.879     -0.297   0.767    -15.554     11.474
# 2    EDUCATION      1.3262      1.108      1.197   0.232     -0.851      3.503
# 3        SOUTH     -0.6975      0.428     -1.628   0.104     -1.539      0.144
# 4          SEX     -2.1443      0.399     -5.370   0.000     -2.929     -1.360
# 5   EXPERIENCE      0.5246      1.109      0.473   0.636     -1.653      2.703
# 6        UNION      1.5168      0.525      2.889   0.004      0.485      2.548
# 7          AGE     -0.4282      1.108     -0.386   0.699     -2.605      1.748
# 8         RACE      0.4786      0.285      1.676   0.094     -0.082      1.039
# 9   OCCUPATION     -0.1527      0.131     -1.165   0.245     -0.410      0.105
# 10      SECTOR      0.7190      0.388      1.855   0.064     -0.042      1.480
# ...

# %%
result_df = result_df.iloc[1:,:]

# %%
result_df
# Out:
# 0                     coef    std err          t   P>|t|     [0.025     0.975]
# 1        const     -2.0402      6.879     -0.297   0.767    -15.554     11.474
# 2    EDUCATION      1.3262      1.108      1.197   0.232     -0.851      3.503
# 3        SOUTH     -0.6975      0.428     -1.628   0.104     -1.539      0.144
# 4          SEX     -2.1443      0.399     -5.370   0.000     -2.929     -1.360
# 5   EXPERIENCE      0.5246      1.109      0.473   0.636     -1.653      2.703
# 6        UNION      1.5168      0.525      2.889   0.004      0.485      2.548
# 7          AGE     -0.4282      1.108     -0.386   0.699     -2.605      1.748
# 8         RACE      0.4786      0.285      1.676   0.094     -0.082      1.039
# 9   OCCUPATION     -0.1527      0.131     -1.165   0.245     -0.410      0.105
# 10      SECTOR      0.7190      0.388      1.855   0.064     -0.042      1.480
# 11        MARR      0.4252      0.420      1.013   0.311     -0.399      1.249

# %%
result_df.columns
# Out:
# Index([, coef, std err, t, P>|t|, [0.025, 0.975]], dtype='object', name=0)

# %%
result_df
# Out:
# 0                     coef    std err          t   P>|t|     [0.025     0.975]
# 1        const     -2.0402      6.879     -0.297   0.767    -15.554     11.474
# 2    EDUCATION      1.3262      1.108      1.197   0.232     -0.851      3.503
# 3        SOUTH     -0.6975      0.428     -1.628   0.104     -1.539      0.144
# 4          SEX     -2.1443      0.399     -5.370   0.000     -2.929     -1.360
# 5   EXPERIENCE      0.5246      1.109      0.473   0.636     -1.653      2.703
# 6        UNION      1.5168      0.525      2.889   0.004      0.485      2.548
# 7          AGE     -0.4282      1.108     -0.386   0.699     -2.605      1.748
# 8         RACE      0.4786      0.285      1.676   0.094     -0.082      1.039
# 9   OCCUPATION     -0.1527      0.131     -1.165   0.245     -0.410      0.105
# 10      SECTOR      0.7190      0.388      1.855   0.064     -0.042      1.480
# 11        MARR      0.4252      0.420      1.013   0.311     -0.399      1.249

# %%
result_df.columns
# Out:
# Index([, coef, std err, t, P>|t|, [0.025, 0.975]], dtype='object', name=0)

# %%
# OLS 결과를 데이터프레임으로 변환
result_df = pd.DataFrame(result.summary().tables[1].data)

# 첫 번째 행을 열 이름으로 설정
column_names = [''] + result_df.iloc[0].str.strip().tolist()[1:]
result_df.columns = column_names

# 첫 번째 행 제거
result_df = result_df[1:]

# %%
result_df
# Out:
#                       coef    std err          t   P>|t|     [0.025     0.975]
# 1        const     -2.0402      6.879     -0.297   0.767    -15.554     11.474
# 2    EDUCATION      1.3262      1.108      1.197   0.232     -0.851      3.503
# 3        SOUTH     -0.6975      0.428     -1.628   0.104     -1.539      0.144
# 4          SEX     -2.1443      0.399     -5.370   0.000     -2.929     -1.360
# 5   EXPERIENCE      0.5246      1.109      0.473   0.636     -1.653      2.703
# 6        UNION      1.5168      0.525      2.889   0.004      0.485      2.548
# 7          AGE     -0.4282      1.108     -0.386   0.699     -2.605      1.748
# 8         RACE      0.4786      0.285      1.676   0.094     -0.082      1.039
# 9   OCCUPATION     -0.1527      0.131     -1.165   0.245     -0.410      0.105
# 10      SECTOR      0.7190      0.388      1.855   0.064     -0.042      1.480
# 11        MARR      0.4252      0.420      1.013   0.311     -0.399      1.249

# %%
result_df['P>|t|'].astype(float)
# Out:
# 1     0.767
# 2     0.232
# 3     0.104
# 4     0.000
# 5     0.636
# 6     0.004
# 7     0.699
# 8     0.094
# 9     0.245
# 10    0.064
# 11    0.311
# Name: P>|t|, dtype: float64

# %%
# OLS 결과를 데이터프레임으로 변환
result_df = pd.DataFrame(result.summary().tables[1].data)

# %%
result_df
# Out:
#              0           1          2          3       4          5          6
# 0                     coef    std err          t   P>|t|     [0.025     0.975]
# 1        const     -2.0402      6.879     -0.297   0.767    -15.554     11.474
# 2    EDUCATION      1.3262      1.108      1.197   0.232     -0.851      3.503
# 3        SOUTH     -0.6975      0.428     -1.628   0.104     -1.539      0.144
# 4          SEX     -2.1443      0.399     -5.370   0.000     -2.929     -1.360
# 5   EXPERIENCE      0.5246      1.109      0.473   0.636     -1.653      2.703
# 6        UNION      1.5168      0.525      2.889   0.004      0.485      2.548
# 7          AGE     -0.4282      1.108     -0.386   0.699     -2.605      1.748
# 8         RACE      0.4786      0.285      1.676   0.094     -0.082      1.039
# 9   OCCUPATION     -0.1527      0.131     -1.165   0.245     -0.410      0.105
# 10      SECTOR      0.7190      0.388      1.855   0.064     -0.042      1.480
# ...

# %%
result_df.iloc[0].astype('str').str.strip().tolist()
# Out:
# ['', 'coef', 'std err', 't', 'P>|t|', '[0.025', '0.975]']

# %%
result_df.iloc[0].astype('str').str.strip().tolist()[1:]
# Out:
# ['coef', 'std err', 't', 'P>|t|', '[0.025', '0.975]']

# %%
x_train
# Out:
#      EDUCATION  SOUTH  SEX  EXPERIENCE  UNION  AGE  RACE  OCCUPATION  SECTOR  \
# 305          9      0    0          33      1   48     3           3       0
# 60          11      0    0          17      0   34     3           6       0
# 309         12      0    1          10      1   28     3           3       0
# 254         16      0    1          27      0   49     3           3       1
# 345         12      1    1          14      0   32     3           3       0
# ..         ...    ...  ...         ...    ...  ...   ...         ...     ...
# 158         14      0    0           2      0   22     3           1       0
# 369         10      1    0          19      0   35     3           4       0
# 25           6      1    0          45      0   57     3           6       1
# 154         12      1    0           1      0   19     3           6       0
# 155         12      0    0          13      0   31     3           6       1
#
#      MARR
# 305     0
# 60      0
# ...

# %%
rfr = RandomForestRegressor()

# %%
df
# Out:
#      EDUCATION  SOUTH  SEX  EXPERIENCE  UNION  AGE  RACE  OCCUPATION  SECTOR  \
# 0            8      0    1          21      0   35     2           6       1
# 1            9      0    1          42      0   57     3           6       1
# 2           12      0    0           1      0   19     3           6       1
# 3           12      0    0           4      0   22     3           6       0
# 4           12      0    0          17      0   35     3           6       0
# ..         ...    ...  ...         ...    ...  ...   ...         ...     ...
# 529         18      0    0           5      0   29     3           5       0
# 530         12      0    1          33      0   51     1           5       0
# 531         17      0    1          25      1   48     1           5       0
# 532         12      1    0          13      1   31     3           5       0
# 533         16      0    0          33      0   55     3           5       1
#
#      MARR   WAGE
# 0       1   5.10
# ...

# %%
rfr = RandomForestRegressor()
rfr.fit(x_train, y_train)

kfold = KFold(n_splits=5)
r2_scores = cross_val_score(rfr, x_train, y_train, cv=kfold, scoring='r2')

print(r2_scores)
print(r2_scores.mean())
# Out:
# [ 0.36681669 -0.10966728  0.00532252  0.24215662  0.2689024 ]
# 0.15470619086556886

# %%
df.describe()
# Out:
#         EDUCATION       SOUTH         SEX  EXPERIENCE       UNION         AGE  \
# count  534.000000  534.000000  534.000000  534.000000  534.000000  534.000000
# mean    13.018727    0.292135    0.458801   17.822097    0.179775   36.833333
# std      2.615373    0.455170    0.498767   12.379710    0.384360   11.726573
# min      2.000000    0.000000    0.000000    0.000000    0.000000   18.000000
# 25%     12.000000    0.000000    0.000000    8.000000    0.000000   28.000000
# 50%     12.000000    0.000000    0.000000   15.000000    0.000000   35.000000
# 75%     15.000000    1.000000    1.000000   26.000000    0.000000   44.000000
# max     18.000000    1.000000    1.000000   55.000000    1.000000   64.000000
#
#              RACE  OCCUPATION      SECTOR        MARR        WAGE
# count  534.000000   534.00000  534.000000  534.000000  534.000000
# mean     2.698502     4.14794    0.275281    0.655431    9.024064
# std      0.679999     1.65580    0.538453    0.475673    5.139097
# ...

# %%
y_pred_train = rfr.predict(x_train)
y_pred_test = rfr.predict(x_test)

print(r2_score(y_train, y_pred_train))
print(r2_score(y_test, y_pred_test))

print('mean_absolute_error')
print(mean_absolute_error(y_train, y_pred_train))
print(mean_absolute_error(y_test, y_pred_test))

print('rmase')
print(np.sqrt(mean_squared_error(y_train, y_pred_train)))
print(np.sqrt(mean_squared_error(y_test, y_pred_test)))

result = pd.DataFrame({'real': y_test, 'pred': y_pred_test})
result['diff'] = result['real'] - result['pred']
sns.scatterplot(data=result, x='real', y='pred')
plt.plot([result['real'].min(), result['real'].max()],[result['real'].min(), result['real'].max()] )
plt.show()

sns.scatterplot(data=result, y='diff', x='pred')
plt.axhline(y=0, color='red')
plt.show()


top20 = pd.Series(rfr.feature_importances_, x_train.columns)
top20 = top20.sort_values(ascending=False)
sns.barplot(x=top20, y=top20.index)
plt.show()

plt.plot(top20.cumsum(), marker='o')
plt.grid(True, axis='y')  # Show only horizontal grid lines
plt.xticks(rotation=45)
plt.show()
# Out:
# 0.8832126271761016
# 0.12286607264796312
# mean_absolute_error
# 1.2835863471849864
# 3.4139658436853004
# rmase
# 1.699837944048578
# 5.128712415053294

# %%
def model_check(model):
    try:
        model.fit(x_train, y_train)

        kfold = KFold(n_splits=5)
        r2_scores = cross_val_score(model, x_train, y_train, cv=kfold, scoring='r2')

        print(r2_scores)
        print(r2_scores.mean())
        
        y_pred_train = model.predict(x_train)
        y_pred_test = model.predict(x_test)

        print(r2_score(y_train, y_pred_train))
        print(r2_score(y_test, y_pred_test))

        print('mean_absolute_error')
        print(mean_absolute_error(y_train, y_pred_train))
        print(mean_absolute_error(y_test, y_pred_test))

        print('rmase')
        print(np.sqrt(mean_squared_error(y_train, y_pred_train)))
        print(np.sqrt(mean_squared_error(y_test, y_pred_test)))

        result = pd.DataFrame({'real': y_test, 'pred': y_pred_test})
        result['diff'] = result['real'] - result['pred']
        sns.scatterplot(data=result, x='real', y='pred')
        plt.plot([result['real'].min(), result['real'].max()],[result['real'].min(), result['real'].max()] )
        plt.show()

        sns.scatterplot(data=result, y='diff', x='pred')
        plt.axhline(y=0, color='red')
        plt.show()


        top20 = pd.Series(model.feature_importances_, x_train.columns)
        top20 = top20.sort_values(ascending=False)
        sns.barplot(x=top20, y=top20.index)
        plt.show()

        plt.plot(top20.cumsum(), marker='o')
        plt.grid(True, axis='y')  # Show only horizontal grid lines
        plt.xticks(rotation=45)
        plt.show()
    except:
        pass

# %%
model_check(rfr)
# Out:
# [ 0.34526551 -0.11358223 -0.00069992  0.25888607  0.30100105]
# 0.158174096604049
# 0.8847471357521729
# 0.12553651796413512
# mean_absolute_error
# 1.2702411987744158
# 3.386434807749186
# rmase
# 1.688633646828087
# 5.120899248848939

# %%
xgb_r = xgb.XGBRegressor()
model_check(xgb_r)
# Out:
# [ 0.20204357 -0.38601123 -0.15768405  0.09958303  0.22813993]
# -0.002785750134606224
# 0.9921009156208125
# 0.01837369373277964
# mean_absolute_error
# 0.20182556496228993
# 3.7584419773232125
# rmase
# 0.44207703162221773
# 5.425608922588162

# %%
lgb_r = lgb.LGBMRegressor()
model_check(lgb_r)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000178 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 129
# [LightGBM] [Info] Number of data points in the train set: 373, number of used features: 10
# [LightGBM] [Info] Start training from score 8.896407
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
np.random.randint(200, 1001, 4)
# Out:
# array([894, 802, 417, 760])

# %%
param_distribution = {
    'n_estimators': np.random.randint(200, 1001, 4),  # Generates 4 random integers between 200 and 1000
    'max_depth': np.random.randint(2, 11, 5)  # Generates 5 random integers between 2 and 10
}


grid = RandomizedSearchCV(rfr, param_distributions=param_distribution, cv=5, scoring='neg_mean_absolute_error', n_iter=10)

# %%
grid.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(),
#                    param_distributions={'max_depth': array([4, 2, 6, 9, 6]),
#                                         'n_estimators': array([621, 938, 858, 878])},
#                    scoring='neg_mean_absolute_error')

# %%
print(grid.best_params_)
print(grid.best_score_)
print(grid.best_estimator_)
# Out:
# {'n_estimators': 878, 'max_depth': 4}
# -3.209971950644005
# RandomForestRegressor(max_depth=4, n_estimators=878)

# %%
rfr  = grid.best_estimator_
model_check(rfr)
# Out:
# [0.31541413 0.00274789 0.17488304 0.29051663 0.38228062]
# 0.2331684606110022
# 0.49207652769656995
# 0.1693777099271765
# mean_absolute_error
# 2.702952207415297
# 3.1497664174354947
# rmase
# 3.5449385922707397
# 4.990880635182927

# %%
import tensorflow as tf

# %%
tf_model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu',input_dim=x_train.shape[1]),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
])

tf_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae', 'mse'])


tf_model.fit(x_train, y_train, epochs=100, batch_size=32, validation_data=(x_test, y_test), verbose=0)

print(tf_model.evaluate(x_test, y_test)[0])
print(tf_model.evaluate(x_test, y_test)[1])
print(tf_model.evaluate(x_test, y_test)[2])

y_pred_train = tf_model.predict(x_train)
y_pred_test = tf_model.predict(x_test)

print(r2_score(y_train, y_pred_train))
print(r2_score(y_test, y_pred_test))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.0696 - mae: 3.4691 - mse: 34.7864
# 26.185129165649414
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.0696 - mae: 3.4691 - mse: 34.7864
# 3.13621187210083
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.0696 - mae: 3.4691 - mse: 34.7864
# 25.193941116333008
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step
# 0.4098324846334388
# 0.15987227239745494

# %%
df.describe()
# Out:
#         EDUCATION       SOUTH         SEX  EXPERIENCE       UNION         AGE  \
# count  534.000000  534.000000  534.000000  534.000000  534.000000  534.000000
# mean    13.018727    0.292135    0.458801   17.822097    0.179775   36.833333
# std      2.615373    0.455170    0.498767   12.379710    0.384360   11.726573
# min      2.000000    0.000000    0.000000    0.000000    0.000000   18.000000
# 25%     12.000000    0.000000    0.000000    8.000000    0.000000   28.000000
# 50%     12.000000    0.000000    0.000000   15.000000    0.000000   35.000000
# 75%     15.000000    1.000000    1.000000   26.000000    0.000000   44.000000
# max     18.000000    1.000000    1.000000   55.000000    1.000000   64.000000
#
#              RACE  OCCUPATION      SECTOR        MARR        WAGE
# count  534.000000   534.00000  534.000000  534.000000  534.000000
# mean     2.698502     4.14794    0.275281    0.655431    9.024064
# std      0.679999     1.65580    0.538453    0.475673    5.139097
# ...

# %%
import shap

# %%
from shap.plots.colors._colors import red_blue, red_blue_circle, red_blue_no_bounds

# %%
# !pip show shap
# !pip show matplotlib
# Out:
# WARNING: Package(s) not found: shap
# Name: matplotlib
# Version: 3.8.3
# Summary: Python plotting package
# Home-page: https://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: matplotlib-users@python.org
# License: PSF
# Location: /opt/anaconda3/lib/python3.11/site-packages
# Requires: contourpy, cycler, fonttools, kiwisolver, numpy, packaging, pillow, pyparsing, python-dateutil
# Required-by: jupyterthemes, optbinning, seaborn

# %%
print(shap_values.shape)
print(shap_values)
# Out:
# (373, 10)
# [[-2.02050719e+00  1.73545463e-02  5.97571068e-01 ... -1.26770977e-01
#   -2.91414880e-02 -8.14644838e-03]
#  [-1.40865472e+00  2.82702713e-02  6.43088240e-01 ...  6.38324755e-02
#   -2.88771366e-02 -1.55268418e-02]
#  [-8.51906876e-01  5.59345507e-02 -8.62111895e-01 ... -6.41162025e-02
#   -2.07609972e-02  8.27957248e-04]
#  ...
#  [-2.33798073e+00 -4.39865778e-02  6.21375875e-01 ...  2.67225615e-02
#    7.85803773e-02  8.48774122e-03]
#  [-7.97800956e-01 -6.71025227e-02  3.19426880e-01 ...  8.48237623e-02
#   -6.52099418e-02 -1.64457776e-02]
#  [-1.07099125e+00  2.93761161e-02  6.76576852e-01 ...  6.56302326e-02
#    8.07825507e-02  8.62007720e-03]]

# %%
if isinstance(shap_values, list):
    # 가정: 첫 번째 출력에 대한 SHAP 값 사용
    shap_values = shap_values[0]

# %%
shap_values.shape
# Out:
# (161, 10)

# %%
x_test.shape
# Out:
# (161, 10)

# %%
explainer = shap.TreeExplainer(rfr, x_train)
shap_values = explainer.shap_values(x_test)



shap.summary_plot(shap_values, feature_names=x_train.columns)
plt.show()

# %%
# print(shap_values.shape)
# feature_names = x_train.columns
# # Ensure feature names are correct
# print(feature_names)

# Plot SHAP summary plot
shap.summary_plot(shap_values, feature_names=feature_names, plot_type="dot")
plt.show()

# %%
red_blue

# %%
shap.summary_plot(shap_values)
